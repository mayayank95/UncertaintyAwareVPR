# %% [markdown]
# <a href="https://colab.research.google.com/github/mayayank95/UncertaintyAwareVPR/blob/main/notebooks/cosplace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_data_folder="/content/drive/MyDrive/Datasets"
data_folder ="/content/datasets"
# !mkdir -p "{data_folder}"

# %%
test_folder_sf_xl=f"{data_folder}/SF_XL/small"
# !mkdir -p "{test_folder_sf_xl}"
# !unzip -q "{drive_data_folder}/SF_XL/small/test.zip" -d "{data_folder}/SF_XL/small"
test_folder_sf_xl=f"{test_folder_sf_xl}/test"

# %%
test_folder_pitts30k=f"{data_folder}/pitts30k"
# !mkdir -p "{test_folder_pitts30k}"
# !tar -xzf "{drive_data_folder}/pitts30k/test.tar.gz" -C "{data_folder}/pitts30k"
test_folder_pitts30k=f"{test_folder_pitts30k}/test"
# !mv /content/datasets/pitts30k/test/queries/ /content/datasets/pitts30k/test/queries_v1/

# %%
test_folder_pitts250k=f"{data_folder}/pitts250k"
# !mkdir -p "{test_folder_pitts250k}"
# !tar -xzf "{drive_data_folder}/pitts250k/test.tar.gz" -C "{data_folder}/pitts250k"
test_folder_pitts250k=f"{test_folder_pitts250k}/test"
# !mv /content/datasets/pitts250k/test/queries/ /content/datasets/pitts250k/test/queries_v1/

# %%
test_folder_nordland=f"{data_folder}/nordland"
# !mkdir -p "{test_folder_nordland}"
# !unzip -q "{drive_data_folder}/nordland/images.zip" -d "{data_folder}/nordland"
test_folder_nordland=f"{test_folder_nordland}/images/test"
# !mv /content/datasets/nordland/images/test/queries/ /content/datasets/nordland/images/test/queries_v1/

# %%
test_folder_amstertime=f"{data_folder}/amstertime"
# !mkdir -p "{test_folder_amstertime}"
# !unzip -q "{drive_data_folder}/amstertime/images.zip" -d "{data_folder}/amstertime"
test_folder_amstertime=f"{test_folder_amstertime}/images/test"
# !mv /content/datasets/amstertime/images/test/queries/ /content/datasets/amstertime/images/test/queries_v1/

# %% [markdown]
# # CosPlace

# %%
# !git clone https://github.com/gmberton/CosPlace.git
# Out:
# Cloning into 'CosPlace'...
# remote: Enumerating objects: 294, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 294 (delta 128), reused 118 (delta 102), pack-reused 118 (from 1)
# Receiving objects: 100% (294/294), 79.15 KiB | 3.60 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
# %cd CosPlace
# !pip install -r requirements.txt
# Out:
# /content/CosPlace
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 69.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Test

# %%
model_path = "/content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth"

# %%
# !python3 eval.py --resume_model "$model_path" --test_set_folder "$test_folder_sf_xl"
# Out:
# 2025-10-29 13:15:37   eval.py --resume_model /content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth --test_set_folder /content/datasets/SF_XL/small/test
# 2025-10-29 13:15:37   Arguments: Namespace(M=10, alpha=30, N=5, L=2, groups_num=8, min_images_per_class=10, backbone='ResNet18', fc_output_dim=512, train_all_layers=False, use_amp16=False, augmentation_device='cuda', batch_size=32, epochs_num=50, iterations_per_epoch=10000, lr=1e-05, classifiers_lr=0.01, image_size=512, resize_test_imgs=False, brightness=0.7, contrast=0.7, hue=0.5, saturation=0.7, random_resized_crop=0.5, infer_batch_size=16, positive_dist_threshold=25, resume_train=None, resume_model='/content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth', device='cuda', seed=0, num_workers=8, num_preds_to_save=0, save_only_wrong_preds=False, test_set_folder='/content/datasets/SF_XL/small/test', save_dir='default', output_folder='logs/default/2025-10-29_13-15-37')
# ...

# %%
# !python3 eval.py --resume_model "$model_path" --test_set_folder "$test_folder_pitts30k"

# %%
# !python3 eval.py --resume_model "$model_path" --test_set_folder "$test_folder_pitts250k"
# Out:
# 2025-11-03 22:10:45   eval.py --resume_model /content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth --test_set_folder /content/datasets/pitts250k/test
# 2025-11-03 22:10:45   Arguments: Namespace(M=10, alpha=30, N=5, L=2, groups_num=8, min_images_per_class=10, backbone='ResNet18', fc_output_dim=512, train_all_layers=False, use_amp16=False, augmentation_device='cuda', batch_size=32, epochs_num=50, iterations_per_epoch=10000, lr=1e-05, classifiers_lr=0.01, image_size=512, resize_test_imgs=False, brightness=0.7, contrast=0.7, hue=0.5, saturation=0.7, random_resized_crop=0.5, infer_batch_size=16, positive_dist_threshold=25, resume_train=None, resume_model='/content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth', device='cuda', seed=0, num_workers=8, num_preds_to_save=0, save_only_wrong_preds=False, test_set_folder='/content/datasets/pitts250k/test', save_dir='default', output_folder='logs/default/2025-11-03_22-10-45')
# ...

# %%
# !python3 eval.py --resume_model "$model_path" --test_set_folder "$test_folder_nordland"
# Out:
# 2025-11-03 21:46:00   eval.py --resume_model /content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth --test_set_folder /content/datasets/nordland/images/test
# 2025-11-03 21:46:00   Arguments: Namespace(M=10, alpha=30, N=5, L=2, groups_num=8, min_images_per_class=10, backbone='ResNet18', fc_output_dim=512, train_all_layers=False, use_amp16=False, augmentation_device='cuda', batch_size=32, epochs_num=50, iterations_per_epoch=10000, lr=1e-05, classifiers_lr=0.01, image_size=512, resize_test_imgs=False, brightness=0.7, contrast=0.7, hue=0.5, saturation=0.7, random_resized_crop=0.5, infer_batch_size=16, positive_dist_threshold=25, resume_train=None, resume_model='/content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth', device='cuda', seed=0, num_workers=8, num_preds_to_save=0, save_only_wrong_preds=False, test_set_folder='/content/datasets/nordland/images/test', save_dir='default', output_folder='logs/default/2025-11-03_21-46-00')
# ...

# %%
# !python3 eval.py --resume_model "$model_path" --test_set_folder "$test_folder_amstertime"
# Out:
# 2025-11-03 22:30:35   eval.py --resume_model /content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth --test_set_folder /content/datasets/amstertime/images/test
# 2025-11-03 22:30:35   Arguments: Namespace(M=10, alpha=30, N=5, L=2, groups_num=8, min_images_per_class=10, backbone='ResNet18', fc_output_dim=512, train_all_layers=False, use_amp16=False, augmentation_device='cuda', batch_size=32, epochs_num=50, iterations_per_epoch=10000, lr=1e-05, classifiers_lr=0.01, image_size=512, resize_test_imgs=False, brightness=0.7, contrast=0.7, hue=0.5, saturation=0.7, random_resized_crop=0.5, infer_batch_size=16, positive_dist_threshold=25, resume_train=None, resume_model='/content/drive/MyDrive/Models/CosPlace/default/2025-10-27_11-48-39/best_model.pth', device='cuda', seed=0, num_workers=8, num_preds_to_save=0, save_only_wrong_preds=False, test_set_folder='/content/datasets/amstertime/images/test', save_dir='default', output_folder='logs/default/2025-11-03_22-30-35')
# ...
